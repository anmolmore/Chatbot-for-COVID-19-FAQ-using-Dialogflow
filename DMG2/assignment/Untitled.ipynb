# %%
import random
import numpy as np
random.seed(11915043)
n = random.random()
print(n)
current_state = np.random.get_state()
current_state
# Out:
# 0.7191981997522685
# ('MT19937', array([2147483648, 1532698171,  886690967, 1979670259, 3733257142,
#         1340903804,   19186138, 2982168380, 3715885657, 4118708158,
#         3270869403,  418430748, 2884210555, 1739375196, 2568373768,
#         2261183258, 3642182805, 3406610220, 1983201979, 3611108593,
#         2683140511, 3698074940, 3308662024, 2068573431, 2385521490,
#         1148225008, 1437082886, 2187957957, 2449155881, 2468056747,
#          308911415, 2090214922, 2657553573,  269147626, 4232893314,
#         1465545430, 2685570720, 2488474947, 1669116674,   86941778,
#         4147346833, 1074234183, 1061653417, 3469832381, 2023147652,
#         1758734500, 3281353995,  510000697,  182359004,  918907493,
#         1231250797, 2607394597, 2413068326,  433232386, 2069906142,
#         4033941581,  787810327,  738965003, 2847904145, 3139526157,
#          901408232, 1652608176, 3229697631,  378316176, 3985759187,
# ...

# %%
n = random.random()
print(n)
# Out:
# 0.6002908985186182
